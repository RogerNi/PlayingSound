# %% [markdown]
# # Rainbow of Sound

# %%
# %matplotlib inline
import sys
sys.path.append('../ThinkDsp')
import thinkdsp
import thinkplot

import matplotlib.pyplot as plt
import numpy as np

from matplotlib import animation, rc
from IPython.display import HTML, Image

resol = 0.0001

rc('animation', html='html5')

# %% [markdown]
# ## Sine function

# %%
f = 0.5
#f = 1/(2 * np.pi) 

a = 1.0

# %%
# period
t = 1/f 

# angular frequency
w = 2*np.pi*f

x = np.arange(0, 2*t, resol)
y = a * np.sin(w*x)

plt.axis([0, 2*t, -3, 3])
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Spectrum of guitar

# %%
wave = thinkdsp.read_wave('A4_guitar.wav')
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.plot(linewidth=1)

# %%
segment = wave.segment(start=1, duration=0.008)
segment.plot(linewidth=1)

# %%
segment = wave.segment(start=1, duration=0.3)
spectrum = segment.make_spectrum()
spectrum.plot(high=3000,linewidth=1)

# %% [markdown]
# ## Linear combination of functions of tones in harmonic series

# %%
# period
t = 2*np.pi

# number of terms
n = 3

a = [1.0, 1.0, 0.5, 0.5, 0.2, 0.1]

# %%
x = np.arange(0, 2*t, resol)
y = np.full(len(x),0)
for i in range(n):
    y = y + a[i] * np.sin(x*(i+1))

plt.axis([0, 2*t, -3, 3])
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Fourier series

# %% [markdown]
# $F(t)$ is a periodic function of whic the period $T$ seconds. Define $\nu = 1/T$.
# $$
# 	F(t) = \frac{1}{2} a_0 + \sum_{n=1}^{\infty} \left( a_n \cos(2n\pi \nu t) + b_n \sin(2n \pi \nu t)  \right)
# $$
#
# \begin{eqnarray*}
# 	a_n & = & 2 \nu \int_{0}^{T} \cos(2n\pi \nu t) F(t) d t \\
# 	b_n & = & 2 \nu \int_{0}^{T} \sin(2n\pi \nu t) F(t) d t
# \end{eqnarray*}

# %%
# period
t = 2*np.pi

resol = t/1000
def plot_p_terms(p):
    x = np.arange(0, 2*t, resol)
    y = np.full(len(x),a[0])
    for i in range(1,p):
        y = y + a[i] * np.sin(x*i)

    plt.axis([0, 2*t, np.max(y)*-1.5, np.max(y)*1.5])
    plt.plot(x, y)
    plt.show()

# %% [markdown]
# ### Example 1

# %%
a = [0.5, 1.0, 0.5, 0.5, 0.2, 0.1]

plot_p_terms(4)

# %%
# %%capture

fig, ax = plt.subplots()
ax.set_xlim(( 0, 12))
ax.set_ylim((-4, 4))
line, = ax.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return (line,)

def animate(i):
    x = np.arange(0, 4*t, resol)
    y = np.full(len(x),a[0])
    for v in range(1,i):
        y = y + a[v] * np.sin(x*v)

    line.set_data(x, y)
    return (line,)

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(a), interval=5000/len(a), blit=True)

# %%
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img6e86b006a4954b5f80e24da1a49e8f85">
#   <div class="anim-controls">
#     <input id="_anim_slider6e86b006a4954b5f80e24da1a49e8f85" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim6e86b006a4954b5f80e24da1a49e8f85.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim6e86b006a4954b5f80e24da1a49e8f85.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim6e86b006a4954b5f80e24da1a49e8f85.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim6e86b006a4954b5f80e24da1a49e8f85.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim6e86b006a4954b5f80e24da1a49e8f85.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim6e86b006a4954b5f80e24da1a49e8f85.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim6e86b006a4954b5f80e24da1a49e8f85.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim6e86b006a4954b5f80e24da1a49e8f85.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim6e86b006a4954b5f80e24da1a49e8f85.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim6e86b006a4954b5f80e24da1a49e8f85.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select6e86b006a4954b5f80e24da1a49e8f85" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_6e86b006a4954b5f80e24da1a49e8f85"
#              >
#       <label for="_anim_radio1_6e86b006a4954b5f80e24da1a49e8f85">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_6e86b006a4954b5f80e24da1a49e8f85"
#              checked>
#       <label for="_anim_radio2_6e86b006a4954b5f80e24da1a49e8f85">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_6e86b006a4954b5f80e24da1a49e8f85"
#              >
#       <label for="_anim_radio3_6e86b006a4954b5f80e24da1a49e8f85">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6e86b006a4954b5f80e24da1a49e8f85";
#     var slider_id = "_anim_slider6e86b006a4954b5f80e24da1a49e8f85";
#     var loop_select_id = "_anim_loop_select6e86b006a4954b5f80e24da1a49e8f85";
#     var frames = new Array(6);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjAsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+17YcXAAARJElEQVR4nO3cfWjV9d/H8dfsZBfmHV5teXM0s6k7\
# Tt3UYxqIeLNp6nBMJSYKmsoqDDJJKKJbWlNJ0q5+IF9KMA0H0c3E5ShvusGUcS5ntssUIyc709Ux\
# FW+Hc32vP6LhLzVXnfn5vs/v+fhr57gdXl+K89z3e85Omu/7vgAAMKaD6wEAAPwdBAwAYBIBAwCY\
# RMAAACYRMACASQQMAGASAQMAmETAAAAmETAAgEkEDABgEgEDAJhEwAAAJhEwAIBJBAwAYBIBAwCY\
# RMAAACYRMACASQQMAGASAQMAmETAAAAmETAAgEkEDABgEgEDAJhEwAAAJhEwAIBJBAwAYBIBAwCY\
# RMAAACYRMACASQQMAGCSqYC1tLRoxIgRKigocD0FAOCYqYCtW7dOkUjE9QwAQACYCVg8HldlZaWW\
# LFniegoAIADMBGzZsmVavXq1OnQ

# %% [markdown]
# ### Example 2

# %%
a = [1.0, 0.8, 0.1, 0.1, 0.2, 0.1]

plot_p_terms(3)

# %%
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(a), interval=5000/len(a), blit=True)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgd4977e45c84f40f2b04f2ae260cdb2c4">
#   <div class="anim-controls">
#     <input id="_anim_sliderd4977e45c84f40f2b04f2ae260cdb2c4" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animd4977e45c84f40f2b04f2ae260cdb2c4.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animd4977e45c84f40f2b04f2ae260cdb2c4.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animd4977e45c84f40f2b04f2ae260cdb2c4.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animd4977e45c84f40f2b04f2ae260cdb2c4.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animd4977e45c84f40f2b04f2ae260cdb2c4.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animd4977e45c84f40f2b04f2ae260cdb2c4.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animd4977e45c84f40f2b04f2ae260cdb2c4.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animd4977e45c84f40f2b04f2ae260cdb2c4.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animd4977e45c84f40f2b04f2ae260cdb2c4.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animd4977e45c84f40f2b04f2ae260cdb2c4.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectd4977e45c84f40f2b04f2ae260cdb2c4" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_d4977e45c84f40f2b04f2ae260cdb2c4"
#              >
#       <label for="_anim_radio1_d4977e45c84f40f2b04f2ae260cdb2c4">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_d4977e45c84f40f2b04f2ae260cdb2c4"
#              checked>
#       <label for="_anim_radio2_d4977e45c84f40f2b04f2ae260cdb2c4">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_d4977e45c84f40f2b04f2ae260cdb2c4"
#              >
#       <label for="_anim_radio3_d4977e45c84f40f2b04f2ae260cdb2c4">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd4977e45c84f40f2b04f2ae260cdb2c4";
#     var slider_id = "_anim_sliderd4977e45c84f40f2b04f2ae260cdb2c4";
#     var loop_select_id = "_anim_loop_selectd4977e45c84f40f2b04f2ae260cdb2c4";
#     var frames = new Array(6);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjAsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+17YcXAAARF0lEQVR4nO3cfWiV9f/H8dexk/0wNZG2nB7Nr03d\
# ceqmO6aBiE43U4djKjFR0FSsMMgkoYhuaU0lSaNALkowDQfRjeJylDfdYMo4OLNhyiInO1NrpuLt\
# fs51/f6Iht/UXHXm53qf3/Px187x7PC6UM5z13WOC/m+7wsAAGM6uR4AAMA/QcAAACYRMACASQQM\
# AGASAQMAmETAAAAmETAAgEkEDABgEgEDAJhEwAAAJhEwAIBJBAwAYBIBAwCYRMAAACYRMACASQQM\
# AGASAQMAmETAAAAmETAAgEkEDABgEgEDAJhEwAAAJhEwAIBJBAwAYBIBAwCYRMAAACYRMACASQQM\
# AGASAQMAmETAAAAmmQpYa2urRowYoaKiItdTAACOmQrY2rVrFY1GXc8AAASAmYAlEglVVlZq0aJF\
# rqcAAALATMCWLl2qVatWqVMnM5M

# %% [markdown]
# ### Example 3

# %%
# f(x) = x
a = [0.0, 2*1.0, -2*1/2, 2*1/3, -2*1/4, 2*1/5, -2*1/6, 2*1/7, -2*1/8, 2*1/9, -2*1/10, 2*1/11, -2*1/12]

plot_p_terms(3)

# %%
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(a), interval=5000/len(a), blit=True)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img0f71e40eaeae44f19edb3f7562d40d64">
#   <div class="anim-controls">
#     <input id="_anim_slider0f71e40eaeae44f19edb3f7562d40d64" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim0f71e40eaeae44f19edb3f7562d40d64.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim0f71e40eaeae44f19edb3f7562d40d64.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim0f71e40eaeae44f19edb3f7562d40d64.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim0f71e40eaeae44f19edb3f7562d40d64.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim0f71e40eaeae44f19edb3f7562d40d64.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim0f71e40eaeae44f19edb3f7562d40d64.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim0f71e40eaeae44f19edb3f7562d40d64.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim0f71e40eaeae44f19edb3f7562d40d64.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim0f71e40eaeae44f19edb3f7562d40d64.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim0f71e40eaeae44f19edb3f7562d40d64.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select0f71e40eaeae44f19edb3f7562d40d64" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_0f71e40eaeae44f19edb3f7562d40d64"
#              >
#       <label for="_anim_radio1_0f71e40eaeae44f19edb3f7562d40d64">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_0f71e40eaeae44f19edb3f7562d40d64"
#              checked>
#       <label for="_anim_radio2_0f71e40eaeae44f19edb3f7562d40d64">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_0f71e40eaeae44f19edb3f7562d40d64"
#              >
#       <label for="_anim_radio3_0f71e40eaeae44f19edb3f7562d40d64">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0f71e40eaeae44f19edb3f7562d40d64";
#     var slider_id = "_anim_slider0f71e40eaeae44f19edb3f7562d40d64";
#     var loop_select_id = "_anim_loop_select0f71e40eaeae44f19edb3f7562d40d64";
#     var frames = new Array(13);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjAsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+17YcXAAARDklEQVR4nO3ceWxUdb/H8U9xxBtkC7EV6IA8WKBD\
# SykwCCaEsLRFoKFhiYFALgikajARiSQa4xprgUikRhPuiZIgKE2MCwSkURaXINhMKGKDcDFS0img\
# g0BYey313D+MDY9sVaf8znee9+uvzjCdfE4g8+45MzTN931fAAAY0871AAAA/g4CBgAwiYABAEwi\
# YAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwi\
# YAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwi\
# YAAAkwgYAMAkAgYAMMlUwJqbmzVkyBAVFxe7ngIAcMxUwCoqKhSJRFzPAAAEgJmAxeNxbdmyRQsX\
# LnQ9BQAQAGYCtnjxYq1YsULt2p

# %% [markdown]
# ### Example 4

# %%
# f(x) = x
a = np.full(40,0.0)
a[0] = 0.0
for i in range(1,40):
    a[i] = 2*(-1)**(i+1) * 1/i

plot_p_terms(3)

# %%
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(a), interval=5000/len(a), blit=True)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img365747a8ac024108ac620569deacac8a">
#   <div class="anim-controls">
#     <input id="_anim_slider365747a8ac024108ac620569deacac8a" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim365747a8ac024108ac620569deacac8a.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim365747a8ac024108ac620569deacac8a.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim365747a8ac024108ac620569deacac8a.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim365747a8ac024108ac620569deacac8a.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim365747a8ac024108ac620569deacac8a.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim365747a8ac024108ac620569deacac8a.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim365747a8ac024108ac620569deacac8a.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim365747a8ac024108ac620569deacac8a.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim365747a8ac024108ac620569deacac8a.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim365747a8ac024108ac620569deacac8a.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select365747a8ac024108ac620569deacac8a" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_365747a8ac024108ac620569deacac8a"
#              >
#       <label for="_anim_radio1_365747a8ac024108ac620569deacac8a">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_365747a8ac024108ac620569deacac8a"
#              checked>
#       <label for="_anim_radio2_365747a8ac024108ac620569deacac8a">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_365747a8ac024108ac620569deacac8a"
#              >
#       <label for="_anim_radio3_365747a8ac024108ac620569deacac8a">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img365747a8ac024108ac620569deacac8a";
#     var slider_id = "_anim_slider365747a8ac024108ac620569deacac8a";
#     var loop_select_id = "_anim_loop_select365747a8ac024108ac620569deacac8a";
#     var frames = new Array(40);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjAsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+17YcXAAARDklEQVR4nO3ceWxUdb/H8U9xxBtkC7EV6IA8WKBD\
# SykwCCaEsLRFoKFhiYFALgikajARiSQa4xprgUikRhPuiZIgKE2MCwSkURaXINhMKGKDcDFS0img\
# g0BYey313D+MDY9sVaf8znee9+uvzjCdfE4g8+45MzTN931fAAAY0871AAAA/g4CBgAwiYABAEwi\
# YAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwi\
# YAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwi\
# YAAAkwgYAMAkAgYAMMlUwJqbmzVkyBAVFxe7ngIAcMxUwCoqKhSJRFzPAAAEgJmAxeNxbdmyRQsX\
# LnQ9BQAQAGYCtnjxYq1YsULt2p

# %% [markdown]
# ### Example 5

# %%
# square wave
a = np.full(50,0.0)
a[0] = 0.0
for m in range(1, 50):
    if (m%2 == 1):
        a[m] = 4/(m*np.pi)

plot_p_terms(3)

# %%
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(a), interval=5000/len(a), blit=True)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img5bc8d581bd43429eb789df0894e9b9cf">
#   <div class="anim-controls">
#     <input id="_anim_slider5bc8d581bd43429eb789df0894e9b9cf" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim5bc8d581bd43429eb789df0894e9b9cf.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim5bc8d581bd43429eb789df0894e9b9cf.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim5bc8d581bd43429eb789df0894e9b9cf.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim5bc8d581bd43429eb789df0894e9b9cf.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim5bc8d581bd43429eb789df0894e9b9cf.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim5bc8d581bd43429eb789df0894e9b9cf.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim5bc8d581bd43429eb789df0894e9b9cf.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim5bc8d581bd43429eb789df0894e9b9cf.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim5bc8d581bd43429eb789df0894e9b9cf.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim5bc8d581bd43429eb789df0894e9b9cf.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select5bc8d581bd43429eb789df0894e9b9cf" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_5bc8d581bd43429eb789df0894e9b9cf"
#              >
#       <label for="_anim_radio1_5bc8d581bd43429eb789df0894e9b9cf">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_5bc8d581bd43429eb789df0894e9b9cf"
#              checked>
#       <label for="_anim_radio2_5bc8d581bd43429eb789df0894e9b9cf">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_5bc8d581bd43429eb789df0894e9b9cf"
#              >
#       <label for="_anim_radio3_5bc8d581bd43429eb789df0894e9b9cf">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5bc8d581bd43429eb789df0894e9b9cf";
#     var slider_id = "_anim_slider5bc8d581bd43429eb789df0894e9b9cf";
#     var loop_select_id = "_anim_loop_select5bc8d581bd43429eb789df0894e9b9cf";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjAsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+17YcXAAARDklEQVR4nO3ceWxUdb/H8U9xxBtkC7EV6IA8WKBD\
# SykwCCaEsLRFoKFhiYFALgikajARiSQa4xprgUikRhPuiZIgKE2MCwSkURaXINhMKGKDcDFS0img\
# g0BYey313D+MDY9sVaf8znee9+uvzjCdfE4g8+45MzTN931fAAAY0871AAAA/g4CBgAwiYABAEwi\
# YAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwi\
# YAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwi\
# YAAAkwgYAMAkAgYAMMlUwJqbmzVkyBAVFxe7ngIAcMxUwCoqKhSJRFzPAAAEgJmAxeNxbdmyRQsX\
# LnQ9BQAQAGYCtnjxYq1YsULt2p

# %% [markdown]
# ## Time window of Fourier transform

# %%
window_width = 0.1
start = 1

# %%
wave = thinkdsp.read_wave('A4_guitar.wav')
segment = wave.segment(start=start, duration=window_width)
spectrum = segment.make_spectrum()
spectrum.plot(high=3000,linewidth=1)
